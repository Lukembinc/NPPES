# %% [markdown]
# # NPPES National Dataset Creator

# %%
# Importing packages
import pandas as pd
import numpy as np

# Setting relevant file paths
dataDict_path = "/Users/lukebincarousky/Downloads/NPPES/NPPES/Dictionaries/main_nppes_data_dict.csv"
fullNPPES_path = "/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_February_2026_V2/npidata_pfile_20050523-20260208.csv"

# Importing geographic workbook
geo = pd.read_excel("/Users/lukebincarousky/Downloads/NPPES/NPPES/Geographic Data/ZIP_Locale_Detail.xls")

# Saving the list of states as a separate variable
state_list = geo['PHYSICAL STATE'].unique()

# %%
# Weekly NPPES file paths
path_1 = "/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_020926_021526_Weekly_V2/npidata_pfile_20260209-20260215.csv"
path_2 = "/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_021626_022226_Weekly_V2/npidata_pfile_20260216-20260222.csv"
path_3 = "/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_022326_022926_Weekly_V2/npidata_pfile_20260223-20260229.csv"
path_4 = "/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_030226_030826_Weekly_V2/npidata_pfile_20260302-20260308.csv"

# %% [markdown]
# # Selecting Relevant Columns

# %%
# Importing our data dictionary
data_dict = pd.read_csv(dataDict_path) # type: ignore

# Creating a list of the columns we need to import using the data dictionary
cols = data_dict['Column_Name'].values

# %% [markdown]
# # Reading Full Data

# %%
df = pd.read_csv(fullNPPES_path, usecols= cols)
print(len(df))
# Out:
# /var/folders/t0/z8cr30h50r79xt4p28kffpfr0000gn/T/ipykernel_1762/1113149153.py:1: DtypeWarning: Columns (24,32,46,56,60,61,64,65,309,310) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fullNPPES_path, usecols= cols)
# 9368082

# %%
print(df.shape)
# Out:
# (9368082, 59)

# %% [markdown]
# # Reading Addition - Week 1

# %%
add = pd.read_csv(path_1, usecols= cols)
print(add.shape)
# Out:
# (30837, 59)
# /var/folders/t0/z8cr30h50r79xt4p28kffpfr0000gn/T/ipykernel_1762/2610804818.py:1: DtypeWarning: Columns (9,24,32,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   add = pd.read_csv("/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_020926_021526_Weekly_V2/npidata_pfile_20260209-20260215.csv", usecols= cols)

# %%
new = pd.concat([df, add], ignore_index=True)
print(new.shape)
# Out:
# (9398919, 59)

# %%
new = new.drop_duplicates()
print(new.shape)
# Out:
# (9398890, 59)

# %% [markdown]
# # Reading Addition - Week 2

# %%
add = pd.read_csv(path_2, usecols= cols)
print(add.shape)
# Out:
# /var/folders/t0/z8cr30h50r79xt4p28kffpfr0000gn/T/ipykernel_1762/3761820789.py:1: DtypeWarning: Columns (24,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   add = pd.read_csv("/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_021626_022226_Weekly_V2/npidata_pfile_20260216-20260222.csv", usecols= cols)
# (28250, 59)

# %%
new = pd.concat([new, add], ignore_index=True)
print(new.shape)
# Out:
# (9396332, 59)

# %%
new = new.drop_duplicates()
print(new.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 new = new.drop_duplicates()
#       2 print(new.shape)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:6818, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6815 inplace = validate_bool_kwarg(inplace, "inplace")
#    6816 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6818 result = self[-self.duplicated(subset, keep=keep)]
#    6819 if ignore_index:
#    6820     result.index = default_index(len(result))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4152, in DataFrame._getitem_bool_array(self, key)
#    4149 key = check_bool_indexer(self.index, key)
#    4151 if key.all():
# -> 4152     return self.copy(deep=None)
#    4154 indexer = key.nonzero()[0]
#    4155 return self._take_with_is_copy(indexer, axis=0)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py:6811, in NDFrame.copy(self, deep)
#    6662 @final
#    6663 def copy(self, deep: bool_t | None = True) -> Self:
#    6664     """
#    6665     Make a copy of this object's indices and data.
#    6666
#    (...)
#    6809     dtype: int64
#    6810     """
# -> 6811     data = self._mgr.copy(deep=deep)
#    6812     self._clear_item_cache()
#    6813     return self._constructor_from_mgr(data, axes=data.axes).__finalize__(
#    6814         self, method="copy"
#    6815     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/internals/managers.py:593, in BaseBlockManager.copy(self, deep)
#     590     else:
#     591         new_axes = list(self.axes)
# --> 593 res = self.apply("copy", deep=deep)
#     594 res.axes = new_axes
#     596 if self.ndim > 1:
#     597     # Avoid needing to re-compute these
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/internals/blocks.py:796, in Block.copy(self, deep)
#     794 refs: BlockValuesRefs | None
#     795 if deep:
# --> 796     values = values.copy()
#     797     refs = None
#     798 else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Reading Addition - Week 3

# %%
#add = pd.read_csv(path_3, usecols= cols)
#print(add.shape)

# %%
#new = pd.concat([new, add], ignore_index=True)
#print(new.shape)

# %%
#new = new.drop_duplicates()
#print(new.shape)

# %% [markdown]
# # Reading Addition - Week 4

# %%
add = pd.read_csv(path_4, usecols= cols)
print(add.shape)

# %%
new = pd.concat([new, add], ignore_index=True)
print(new.shape)

# %%
new = new.drop_duplicates()
print(new.shape)
