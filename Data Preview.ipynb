# %% [markdown]
# # Data Preview

# %%
import pandas as pd

# Select state and scope
state = "MA"  # (use abbreviation, e.g., 'CA' for California)
scope = "Full Data"  # Options: "Full Data", "Dental"

# Establishing the results file path
results_path = f"/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_May_2026_V2/{scope}/{state} NPPES Extract.csv"

df = pd.read_csv(results_path, low_memory=False)

# %%
df
# Out:
#                NPI Employer Identification Number (EIN)  \
# 0       1982607917                                  NaN
# 1       1790788743                            <UNAVAIL>
# 2       1023011061                                  NaN
# 3       1588667539                                  NaN
# 4       1023011228                                  NaN
# ...            ...                                  ...
# 254204  1871421024                                  NaN
# 254205  1598693749                                  NaN
# 254206  1104754357                                  NaN
# 254207  1942138102                                  NaN
# 254208  1124956362                                  NaN
#
#        Provider Organization Name (Legal Business Name)  \
# 0                                                   NaN
# 1                   CHICOPEE VISITING NURSE ASSOCIATION
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 254204                                              NaN
# 254205                                              NaN
# 254206                                              NaN
# 254207                                              NaN
# 254208                                              NaN
#
#        Provider Last Name (Legal Name) Provider First Name  \
# 0                              ROWLAND           FREDERICK
# 1                                  NaN                 NaN
# 2                               LETIEN              WALTER
# 3                               ZALLEN               BARRY
# 4                              HARADON               TRACY
# ...                                ...                 ...
# 254204                          LOWELL             KENNETH
# 254205                         EVERSON              DANIEL
# 254206                         O'HAIRE                JOHN
# 254207                         CORTESE           ELISABETH
# 254208                           ZAIDI               HUMZA
#
#        Provider Middle Name Provider Name Prefix Text  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                      CARY                       DR.
# 3                     GRANT                       DR.
# 4                         A                       NaN
# ...                     ...                       ...
# 254204                 EVAN                       NaN
# 254205                  NaN                       NaN
# 254206               DALTON                       NaN
# 254207             ISABELLA                       NaN
# 254208                  NaN                       NaN
#
#        Provider Name Suffix Text Provider Credential Text  \
# 0                            NaN                       MD
# 1                            NaN                      NaN
# 2                            NaN                    AU.D.
# 3                            NaN                     M.D.
# 4                            NaN                    O. D.
# ...                          ...                      ...
# 254204                       NaN                      NaN
# 254205                       NaN                      NaN
# 254206                       NaN                      NaN
# 254207                       NaN                      NaN
# 254208                       NaN                      NaN
#
#        Provider First Line Business Mailing Address  ... Class_3 Spec_3  \
# 0                                    1200 CENTRE ST  ...     NaN    NaN
# 1                                  2024 WESTOVER RD  ...     NaN    NaN
# 2                                      266 CABOT ST  ...     NaN    NaN
# 3                                     130 DRAPER RD  ...     NaN    NaN
# 4                                    453 SUMNER AVE  ...     NaN    NaN
# ...                                             ...  ...     ...    ...
# 254204                                  55 TOZER RD  ...     NaN    NaN
# 254205                                 38 SCHOOL ST  ...     NaN    NaN
# 254206                             24 MAIN ST APT 2  ...     NaN    NaN
# 254207                             145 BOYLSTON CIR  ...     NaN    NaN
# 254208                               10 SKY VIEW DR  ...     NaN    NaN
#
#        Code_4 Grouping_4 Class_4  Spec_4  Code_5 Grouping_5 Class_5 Spec_5
# 0         NaN        NaN     NaN     NaN     NaN        NaN     NaN    NaN
# 1         NaN        NaN     NaN     NaN     NaN        NaN     NaN    NaN
# 2         NaN        NaN     NaN     NaN     NaN        NaN     NaN    NaN
# 3         NaN        NaN     NaN     NaN     NaN        NaN     NaN    NaN
# 4         NaN        NaN     NaN     NaN     NaN        NaN     NaN    NaN
# ...       ...        ...     ...     ...     ...        ...     ...    ...
# 254204    NaN        NaN     NaN     NaN     NaN        NaN     NaN    NaN
# 254205    NaN        NaN     NaN     NaN     NaN        NaN     NaN    NaN
# 254206    NaN        NaN     NaN     NaN     NaN        NaN     NaN    NaN
# 254207    NaN        NaN     NaN     NaN     NaN        NaN     NaN    NaN
# 254208    NaN        NaN     NaN     NaN     NaN        NaN     NaN    NaN
#
# [254209 rows x 81 columns]
