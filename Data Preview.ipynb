# %% [markdown]
# # Data Preview

# %%
import pandas as pd

# Select state (use abbreviation, e.g., 'CA' for California)
state = "CA"  # Change this to the desired state abbreviation

# Establishing the results file path
results_path = f"/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_May_2026_V2/States/{state} NPPES Extract.csv"

df = pd.read_csv(results_path, low_memory=False)

# %%
df
# Out:
#                 NPI Employer Identification Number (EIN)  \
# 0        1023011178                            <UNAVAIL>
# 1        1023011053                            <UNAVAIL>
# 2        1801899836                                  NaN
# 3        1467455410                                  NaN
# 4        1215930250                                  NaN
# ...             ...                                  ...
# 1153137  1134057391                                  NaN
# 1153138  1861320020                                  NaN
# 1153139  1689502841                                  NaN
# 1153140  1033047295                            <UNAVAIL>
# 1153141  1588592745                                  NaN
#
#         Provider Organization Name (Legal Business Name)  \
# 0                                         COLLABRIA CARE
# 1                VINE DISCOUNT PHARMACY & MEDICAL SUPPLY
# 2                                                    NaN
# ...

# %% [markdown]
# - Mapping Specialties to Taxonomy
# - Cleaning City column
# - ZipCode to 5 digits
# - Adding County

# %%
df['Provider Business Mailing Address Postal Code'] = df['Provider Business Mailing Address Postal Code'].astype(str).str[:5]
df['Provider Business Practice Location Address Postal Code'] = df['Provider Business Practice Location Address Postal Code'].astype(str).str[:5]

# %%
df['Provider Business Mailing Address Telephone Number'] = df['Provider Business Mailing Address Telephone Number'].astype(str).str[:10]
df['Provider Business Mailing Address Fax Number'] = df['Provider Business Mailing Address Fax Number'].astype(str).str[:10]
df['Provider Business Practice Location Address Telephone Number'] = df['Provider Business Practice Location Address Telephone Number'].astype(str).str[:10]
df['Provider Business Practice Location Address Fax Number'] = df['Provider Business Practice Location Address Fax Number'].astype(str).str[:10]
df['Authorized Official Telephone Number'] = df['Authorized Official Telephone Number'].astype(str).str[:10]

# %%
df.iloc[0]
# Out:
# NPI                                                                                                  1023011178
# Employer Identification Number (EIN)                                                                  <UNAVAIL>
# Provider Organization Name (Legal Business Name)                                                 COLLABRIA CARE
# Provider Last Name (Legal Name)                                                                             NaN
# Provider First Name                                                                                         NaN
# Provider Middle Name                                                                                        NaN
# Provider Name Prefix Text                                                                                   NaN
# Provider Name Suffix Text                                                                                   NaN
# ...

# %%
df
# Out:
#                 NPI Employer Identification Number (EIN)  \
# 0        1023011178                            <UNAVAIL>
# 1        1023011053                            <UNAVAIL>
# 2        1801899836                                  NaN
# 3        1467455410                                  NaN
# 4        1215930250                                  NaN
# ...             ...                                  ...
# 1153137  1134057391                                  NaN
# 1153138  1861320020                                  NaN
# 1153139  1689502841                                  NaN
# 1153140  1033047295                            <UNAVAIL>
# 1153141  1588592745                                  NaN
#
#         Provider Organization Name (Legal Business Name)  \
# 0                                         COLLABRIA CARE
# 1                VINE DISCOUNT PHARMACY & MEDICAL SUPPLY
# 2                                                    NaN
# ...

# %%
'Provider Business Practice Location Address City Name'
# Out:
# 'Provider Business Practice Location Address City Name'

# %%
'Healthcare Provider Taxonomy Code_1'
# Out:
# 'Healthcare Provider Taxonomy Code_1'
