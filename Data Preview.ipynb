# %% [markdown]
# # Data Preview

# %%
import pandas as pd

# Select state (use abbreviation, e.g., 'CA' for California)
state = "CA"  # Change this to the desired state abbreviation

# Establishing the results file path
results_path = f"/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_April_2026_V2/V1 States/{state} NPPES Extract.csv"

df = pd.read_csv(results_path, low_memory=False)

# %%
df
# Out:
#            index         NPI Employer Identification Number (EIN)  \
# 0              5  1023011178                            <UNAVAIL>
# 1             73  1023011053                            <UNAVAIL>
# 2             98  1801899836                                  NaN
# 3            144  1467455410                                  NaN
# 4            185  1215930250                                  NaN
# ...          ...         ...                                  ...
# 1145587  9494395  1679416903                                  NaN
# 1145588  9494406  1487597712                            <UNAVAIL>
# 1145589  9494414  1568305894                                  NaN
# 1145590  9494431  1639012966                                  NaN
# 1145591  9494432  1548103872                                  NaN
#
#         Provider Organization Name (Legal Business Name)  \
# 0                                         COLLABRIA CARE
# ...

# %%
# Establishing the results file path
results2_path = f"/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_April_2026_V2/V2 States/{state} NPPES Extract.csv"

df_2 = pd.read_csv(results2_path, low_memory=False)

# %%
df_2
# Out:
#                 NPI Employer Identification Number (EIN)  \
# 0        1023011178                            <UNAVAIL>
# 1        1023011053                            <UNAVAIL>
# 2        1801899836                                  NaN
# 3        1467455410                                  NaN
# 4        1215930250                                  NaN
# ...             ...                                  ...
# 1145587  1679416903                                  NaN
# 1145588  1487597712                            <UNAVAIL>
# 1145589  1568305894                                  NaN
# 1145590  1639012966                                  NaN
# 1145591  1548103872                                  NaN
#
#         Provider Organization Name (Legal Business Name)  \
# 0                                         COLLABRIA CARE
# 1                VINE DISCOUNT PHARMACY & MEDICAL SUPPLY
# 2                                                    NaN
# ...
