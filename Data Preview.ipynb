# %% [markdown]
# # Data Preview

# %%
import pandas as pd

# Select state and scope
state = "MA"  # (use abbreviation, e.g., 'CA' for California)
scope = "Dental"  # Options: "Full Data", "Dental"
format = "parquet" # Options: "csv", "parquet"

# Establishing the results file path
if format == "csv":
    if scope == "Full Data":
        results_path = f"/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_June_2026_V2/{scope}/{state} NPPES Extract.csv"
    else:
        results_path = f"/Users/lukebincarousky/Downloads/NPPES/NPPES_Data_Dissemination_June_2026_V2/{scope}/{state} NPPES Dental.csv"
if format == "parquet":
    if scope == "Full Data":
        print("Parquet format is currently only available for Dental scope. Defaulting to Dental scope.")
    results_path = f"/Users/lukebincarousky/Downloads/NPPES/NPPES/data/NPPES_Data_Dissemination_June_2026_V2/Dental/{state} NPPES Dental.parquet"

if format == "csv":
    df = pd.read_csv(results_path, low_memory=False)
elif format == "parquet":
    df = pd.read_parquet(results_path)

# %%
df
# Out:
#               NPI Provider Name Prefix Text Provider First Name  \
# 0      1841293834                       DR.               KEVIN
# 1      1174526172                       DR.                MAHA
# 2      1073516068                       DR.              STEVEN
# 3      1265435028                       DR.                ADAM
# 4      1558364521                       DR.              RAMONA
# ...           ...                       ...                 ...
# 14448  1740871227                      None                None
# 14449  1619640380                      None          TAPHAPHENE
# 14450  1396415295                      None                None
# 14451  1386424786                      None                None
# 14452  1770347858                      None                None
#
#       Provider Middle Name Provider Last Name (Legal Name)  \
# 0                     None                           WELLS
# 1                        G                         BOUTROS
# 2                       A.                          CORBEN
# 3                     None                           ORDEN
# 4                       L.                          LEEMAN
# ...                    ...                             ...
# 14448                 None                            None
# 14449                 None                           YOUNG
# 14450                 None                            None
# 14451                 None                            None
# 14452                 None                            None
#
#       Provider Name Suffix Text Provider Credential Text Provider Sex Code  \
# 0                          None                   D.M.D.                 M
# 1                          None                   D.M.D.                 F
# 2                          None                   D.M.D.                 M
# 3                          None                  DDS, MS                 M
# 4                          None                      DDS                 F
# ...                         ...                      ...               ...
# 14448                      None                     None              None
# 14449                      None                      DMD                 F
# 14450                      None                     None              None
# 14451                      None                     None              None
# 14452                      None                     None              None
#
#       Enumeration Date Last Update Date  ... Is Organization Subpart  \
# 0           05/23/2005       07/08/2007  ...                    None
# 1           05/23/2005       07/08/2007  ...                    None
# 2           05/23/2005       07/08/2007  ...                    None
# 3           05/24/2005       07/08/2007  ...                    None
# 4           05/24/2005       07/08/2007  ...                    None
# ...                ...              ...  ...                     ...
# 14448       01/28/2021       01/28/2021  ...                       N
# 14449       07/28/2021       10/16/2023  ...                    None
# 14450       09/14/2021       09/14/2021  ...                       N
# 14451       10/03/2023       10/03/2023  ...                       N
# 14452       02/09/2024       02/09/2024  ...                       N
#
#        Parent Organization LBN Parent Organization TIN  \
# 0                         None                    None
# 1                         None                    None
# 2                         None                    None
# 3                         None                    None
# 4                         None                    None
# ...                        ...                     ...
# 14448                     None                    None
# 14449                     None                    None
# 14450                     None                    None
# 14451                     None                    None
# 14452                     None                    None
#
#              Business Address Business Address2 Business Address City  \
# 0            793 LYNNFIELD ST              None                  LYNN
# 1           50 ROLLINGWOOD LN              None               CONCORD
# 2              301 NEWBURY ST              None               DANVERS
# 3              1330 BEACON ST           STE 344             BROOKLINE
# 4              1051 BEACON ST           STE 409             BROOKLINE
# ...                       ...               ...                   ...
# 14448        161 ASH ST STE B              None               READING
# 14449            217 SOUTH ST              None               HOLYOKE
# 14450  169 LINCOLN ST STE 101              None               HINGHAM
# 14451             474 MAIN ST              None                WOBURN
# 14452       87 ELM ST STE 302              None             HOPKINTON
#
#       Business Address State Business Address ZipCode  \
# 0                         MA                    01904
# 1                         MA                    01742
# 2                         MA                    01923
# 3                         MA                    02446
# 4                         MA                    02446
# ...                      ...                      ...
# 14448                     MA                    01867
# 14449                     MA                    01040
# 14450                     MA                    02043
# 14451                     MA                    01801
# 14452                     MA                    01748
#
#       Business Address Telephone Business Address Fax
# 0                     7815993380           7815993385
# 1                     9783696176           9782875843
# 2                     9787627411                 None
# 3                     6172776700           6172328931
# 4                     6172770033           6177396800
# ...                          ...                  ...
# 14448                 7819446761                 None
# 14449                 4133191078                 None
# 14450                 7817400100           7817404590
# 14451                 7816043999                 None
# 14452                 5085898270                 None
#
# [14453 rows x 68 columns]
